# %%
import pandas as pd
import numpy as np
from random import randint
from random import random
df = pd.read_csv("genres_V2.csv")
df = df.drop(columns = ["title", "analysis_url", "id"])
fields = {"Fields":[str(x) for x in df.columns], "Types":[str(df[x].dtype) for x in df.columns], 
         "Missing Data": ["True" if df[x].isnull().any() else "False" for x in df.columns]}
display(df.sample(10))
display(df.info())
fields_DataFrame = pd.DataFrame(data=fields)
display(fields_DataFrame)

df["duration_ms"] = [-x if randint(0,10) == 3 else x for x in df["duration_ms"].values]
df["loudness"] = [randint(70, 120) if randint(0,100) == 42 else x for x in df["loudness"].values]
df["key"] = [x+random() for x in df["key"].values]
display(df.sample(5))
# Out:
# /var/folders/n8/hdnfk3kd3p1d7wvb85hj9zv40000gn/T/ipykernel_75488/3991896940.py:5: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("genres_V2.csv")
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 18870         0.801   0.825   10    -6.576     0       0.3230       0.12500
# 24147         0.858   0.737    1   -10.935     0       0.0692       0.00809
# 41374         0.493   0.922    6    -5.865     1       0.0460       0.00056
# 5288          0.615   0.648    5    -3.792     0       0.2200       0.04110
# 36872         0.600   0.798    0    -5.698     1       0.1880       0.28000
# 40250         0.465   0.902    0    -5.689     0       0.0667       0.00108
# 25500         0.716   0.372    1   -13.959     1       0.0538       0.02920
# 3963          0.586   0.861    6    -7.639     1       0.0863       0.32400
# 26895         0.794   0.898    0   -12.352     1       0.1360       0.00488
# 26761         0.684   0.957   11    -7.345     0       0.1330       0.00104
#
#        instrumentalness  liveness  valence    tempo            type  \
# 18870          0.000005    0.2710   0.7180  187.720  audio_features
# 24147          0.431000    0.0883   0.6680  123.009  audio_features
# 41374          0.011500    0.7250   0.0802  149.864  audio_features
# 5288           0.000000    0.2770   0.2600  169.912  audio_features
# 36872          0.000000    0.1100   0.3850  173.903  audio_features
# 40250          0.409000    0.3390   0.0690  150.372  audio_features
# 25500          0.878000    0.0989   0.1780  127.016  audio_features
# 3963           0.978000    0.0991   0.3640  159.972  audio_features
# 26895          0.946000    0.1050   0.0283  128.031  audio_features
# 26761          0.464000    0.6390   0.1330  131.989  audio_features
#
#                                         uri  \
# 18870  spotify:track:18bsblFzs3PgmtFsuFLkSD
# 24147  spotify:track:4Byuz6YlTC4oXhEEKDwnEH
# 41374  spotify:track:2FaFLADnoPY6xPaFmwK7l2
# 5288   spotify:track:29UgEHyxg63NDzckA3hLk5
# 36872  spotify:track:3XN8pSN4Ax0dIuFhBhz4lP
# 40250  spotify:track:7bUwVy2be8nAKF1Jsywaps
# 25500  spotify:track:0HoMFWCY6OevJc0GUajfUM
# 3963   spotify:track:1fthrv86GaelWZ232Vkqq3
# 26895  spotify:track:4RFo4tmdWD756ox2Ykh5nz
# 26761  spotify:track:6JVHEzoGwqK9T1xEKB76LN
#
#                                               track_href  duration_ms  \
# 18870  https://api.spotify.com/v1/tracks/18bsblFzs3Pg...       309093
# 24147  https://api.spotify.com/v1/tracks/4Byuz6YlTC4o...       374392
# 41374  https://api.spotify.com/v1/tracks/2FaFLADnoPY6...       296071
# 5288   https://api.spotify.com/v1/tracks/29UgEHyxg63N...       223147
# 36872  https://api.spotify.com/v1/tracks/3XN8pSN4Ax0d...       207055
# 40250  https://api.spotify.com/v1/tracks/7bUwVy2be8nA...       195107
# 25500  https://api.spotify.com/v1/tracks/0HoMFWCY6Oev...       489590
# 3963   https://api.spotify.com/v1/tracks/1fthrv86Gael...       222000
# 26895  https://api.spotify.com/v1/tracks/4RFo4tmdWD75...       481458
# 26761  https://api.spotify.com/v1/tracks/6JVHEzoGwqK9...       412727
#
#        time_signature            genre                    song_name  \
# 18870               4           Hiphop                   Fallin' Up
# 24147               4        techhouse                          NaN
# 41374               4        hardstyle                          NaN
# 5288                4  Underground Rap  Lockjaw (feat. Kodak Black)
# 36872               4              dnb                          NaN
# 40250               4        hardstyle                          NaN
# 25500               4           techno                          NaN
# 3963                4        Dark Trap                        Polar
# 26895               4           techno                          NaN
# 26761               4           techno                          NaN
#
#        Unnamed: 0
# 18870         NaN
# 24147      2644.0
# 41374     20046.0
# 5288          NaN
# 36872     15471.0
# 40250     18900.0
# 25500      4018.0
# 3963          NaN
# 26895      5434.0
# 26761      5298.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42305 entries, 0 to 42304
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      42305 non-null  float64
#  1   energy            42305 non-null  float64
#  2   key               42305 non-null  int64
#  3   loudness          42305 non-null  float64
#  4   mode              42305 non-null  int64
#  5   speechiness       42305 non-null  float64
#  6   acousticness      42305 non-null  float64
#  7   instrumentalness  42305 non-null  float64
#  8   liveness          42305 non-null  float64
#  9   valence           42305 non-null  float64
#  10  tempo             42305 non-null  float64
#  11  type              42305 non-null  object
#  12  uri               42305 non-null  object
#  13  track_href        42305 non-null  object
#  14  duration_ms       42305 non-null  int64
#  15  time_signature    42305 non-null  int64
#  16  genre             42305 non-null  object
#  17  song_name         21519 non-null  object
#  18  Unnamed: 0        20780 non-null  float64
# dtypes: float64(10), int64(4), object(5)
# memory usage: 6.1+ MB
# None
#               Fields    Types Missing Data
# 0       danceability  float64        False
# 1             energy  float64        False
# 2                key    int64        False
# 3           loudness  float64        False
# 4               mode    int64        False
# 5        speechiness  float64        False
# 6       acousticness  float64        False
# 7   instrumentalness  float64        False
# 8           liveness  float64        False
# 9            valence  float64        False
# 10             tempo  float64        False
# 11              type   object        False
# 12               uri   object        False
# 13        track_href   object        False
# 14       duration_ms    int64        False
# 15    time_signature    int64        False
# 16             genre   object        False
# 17         song_name   object         True
# 18        Unnamed: 0  float64         True
#        danceability  energy        key  loudness  mode  speechiness  \
# 27097         0.667  0.8160  11.606411   -12.629     1       0.0473
# 40411         0.462  0.9800   7.165569    -3.399     0       0.0601
# 13478         0.561  0.0587   5.123177   -17.819     1       0.0762
# 30540         0.664  0.9660   7.910407    -5.516     1       0.0467
# 21961         0.800  0.6200  10.421614    -7.346     0       0.0531
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 27097      0.043400           0.85800    0.1680   0.0344  135.007
# 40411      0.001110           0.00649    0.3930   0.2270  150.024
# 13478      0.950000           0.00000    0.0828   0.3420  143.027
# 30540      0.000008           0.77800    0.9780   0.7020  148.012
# 21961      0.004120           0.78000    0.1270   0.3870  125.971
#
#                  type                                   uri  \
# 27097  audio_features  spotify:track:60aKgTrrbOSNFV4qx1tJcF
# 40411  audio_features  spotify:track:1UjBFz7vGpyOGFELYtAWDr
# 13478  audio_features  spotify:track:06qUEhhx6jKQmhj2qAkn4H
# 30540  audio_features  spotify:track:6haWPaRyuoGxqtOIgk8mmt
# 21961  audio_features  spotify:track:4bnQkhierSkBduFvdDwQk9
#
#                                               track_href  duration_ms  \
# 27097  https://api.spotify.com/v1/tracks/60aKgTrrbOSN...       351378
# 40411  https://api.spotify.com/v1/tracks/1UjBFz7vGpyO...       244408
# 13478  https://api.spotify.com/v1/tracks/06qUEhhx6jKQ...      -222468
# 30540  https://api.spotify.com/v1/tracks/6haWPaRyuoGx...       468831
# 21961  https://api.spotify.com/v1/tracks/4bnQkhierSkB...       243810
#
#        time_signature      genre       song_name  Unnamed: 0
# 27097               4     techno             NaN      5639.0
# 40411               4  hardstyle             NaN     19067.0
# 13478               1        Emo  Trying My Best         NaN
# 30540               4  psytrance             NaN      9088.0
# 21961               4  techhouse             NaN       441.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
